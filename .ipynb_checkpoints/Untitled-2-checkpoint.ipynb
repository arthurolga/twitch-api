# %%
import pymysql
from functools import partial
import requests
import networkx as nx
import freeman as fm
from config import *
from datetime import datetime, timedelta
import matplotlib.pyplot as plt

def run_db_query(connection, query, args=None):
    with connection.cursor() as cursor:
        print('Executando query:')
        cursor.execute(query, args)
        for result in cursor:
            print(result)

connection = pymysql.connect(
    host=myhost,
    user=myuser,
    password=mypass,
    database='twitch')


db = partial(run_db_query, connection)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
def get_games(conn):
    with conn.cursor() as cursor:
        cursor.execute(
            'SELECT * FROM game')
        res = cursor.fetchall()
        if res:
            return res
        else:
            return None
        
def get_links(conn):
    with conn.cursor() as cursor:
        cursor.execute(
            'SELECT * FROM links')
        res = cursor.fetchall()
        if res:
            return res
        else:
            return None

def get_links_from_game(conn,game):
    with conn.cursor() as cursor:
        cursor.execute(
            'SELECT * FROM links WHERE links_game_name = %s',(game))
        res = cursor.fetchall()
        if res:
            return res
        else:
            return None
        
        
# def get_username_from_link(conn,game):
#     with conn.cursor() as cursor:
#         cursor.execute(
#             '''SELECT streamer_display_name FROM streamer
#             INNER JOIN on 
#             WHERE streamer_id = %s''',(game))
#         res = cursor.fetchall()
#         if res:
#             return res
#         else:
#             return None
        
def get_username_from_id(conn,_id):
    with conn.cursor() as cursor:
        cursor.execute(
            'SELECT streamer_display_name FROM streamer WHERE streamer_id = %s',(_id))
        res = cursor.fetchone()
        if res:
            return res
        else:
            return None
        
def get_streamer_id_from_game(conn,game_id):
    with conn.cursor() as cursor:
        cursor.execute(
            'SELECT stream_user_id FROM twitch.stream WHERE stream_game_id = %s GROUP BY stream_user_id ;',(game_id))
        res = cursor.fetchall()
        if res:
            return res
        else:
            return None
def get_total_viewer_count(conn,username):
    with conn.cursor() as cursor:
        cursor.execute("SELECT streamer_view_count FROM twitch.streamer WHERE streamer_display_name = %s",(username))
        res=cursor.fetchone()
        if res:
            return res
        else:
            return None
    
    
        
def get_streams_from_game(conn,time1,time2,game):
    with conn.cursor() as cursor:
        cursor.execute(
            'SELECT * FROM stream WHERE stream_game_id = %s AND stream_request_time BETWEEN %s AND %s order by stream_viewer_count desc',(game, time1, time2))
        res = cursor.fetchall()
        if res:
            return res
        else:
            return None

def get_time(conn,time_1,time_2,game_id):
    #print(time_1,time_2,game_id)
    r = get_streams_from_game(conn,time_1,time_2,game_id)
    #print(r)
    sizes = {}
    if r:
        for node in r:
            sizes[node[2]] = node[6]
    return sizes

def get_progression(conn,start_date,end_date,game_id):
    lista = []
    data = start_date
    while(data < end_date):
        lista.append(get_time(conn,str(data),str(data+timedelta(minutes=10)),game_id))
        data += timedelta(minutes=30)
    return lista

# %%
time1 = '2019-11-13 13:00:00'
time2 = '2019-11-13 13:10:00'
time3 = '2019-11-13 13:30:00'
time4 = '2019-11-13 13:40:00'


game = '21779' # LOL

def list_streamer_time(time1,time2,game):
    totalview=0
    streams_lol = get_streams_from_game(connection,time1,time2,game)
    Slist=[]
    for a in streams_lol:
        totalview=totalview+a[6]
        Slist.append((a[2],a[6],a[1],a[8])) # user name, viewer count, user id, request time
    return Slist,totalview
streams1=(list_streamer_time(time1,time2,game))
streams2=(list_streamer_time(time3,time4,game))

# %%
#print(streams1[0:30])
#print(streams2)

def filter_value( someList, value ):
    for x, y,z,w in someList:
        if x == value :
            yield x,y
            

def get_leavers(list1,list2):
    leavers=[]
    for i in list1[0:30]:
        result=list( filter_value(list2, i[0]))
        if result==[]:
            leavers.append([i[0],i[2]])
    return leavers
        
get_leavers(streams1[0],streams2[0])
# Out:
# [['Faker', 43691],
#  ['괴물쥐123', 148057505],
#  ['RATIRL', 57292293],
#  ['테디이', 152714599],
#  ['lol_Khan', 146647519],
#  ['clid', 146466793]]

# %%
import pandas as pd 
time1 = datetime(2019, 11, 11, 0, 0)
time2 = datetime(2019, 11, 11, 23, 0)


def get_links_from_to(conn,from_id,to_id):
    with conn.cursor() as cursor:
        cursor.execute(
            'SELECT * FROM links WHERE from_id = %s AND to_id = %s',(from_id, to_id))
        res = cursor.fetchall()
        if res:
            return res
        else:
            return None

# %%
def links_dict(conn,game_name):
    with conn.cursor() as cursor:
        cursor.execute(
            '''
            SELECT st1.streamer_display_name, st2.streamer_display_name FROM links
            INNER JOIN streamer st1 ON links.from_id = st1.streamer_id
            INNER JOIN streamer st2 ON links.to_id = st2.streamer_id
            WHERE links_game_name LIKE %s LIMIT 8000
            ''',(game_name))
        res = cursor.fetchall()
        if res:
            return res
        else:
            return None
        
dict_lol = links_dict(connection, "League of Legends")
print(dict_lol)
print(len(dict_lol))
# Out:
# (('Faker', '매드라이프_'), ('Multiplayer', 'KayPeaLoL'), ('Multiplayer', 'wtcN'), ('Multiplayer', 'AlperBicen'), ('Dekar173', 'imaqtpie'), ('Dekar173', 'IWillDominate'), ('Dekar173', 'imls'), ('Dekar173', 'Shiphtur'), ('Dekar173', 'Wingsofdeath'), ('Dekar173', 'SoloRenektonOnly'), ('Dekar173', 'ESL_LOL'), ('Dekar173', 'wickd'), ('Dekar173', 'boxbox'), ('Dekar173', 'NickiTaylor'), ('Dekar173', '1Adrianaries1'), ('Dekar173', 'Akaadian'), ('Dekar173', 'Rakin'), ('Dekar173', 'HanjaroLoL'), ('Dekar173', 'loltyler1'), ('Dekar173', 'JenaUrf'), ('Dekar173', 'Elite500'), ('Dekar173', 'Viper'), ('Dekar173', 'RATIRL'), ('Dekar173', 'luxxbunny'), ('Dekar173', 'TFBlade'), ('Dekar173', 'ipav999'), ('Dekar173', 'PinkWardlol'), ('Dekar173', 'MaryMaybe'), ('Dekar173', 'HeisendongNA'), ('Dekar173', 'STPeach'), ('Dekar173', 'TrackingThePros'), ('Dekar173', 'Barbaholic'), ('Dekar173', 'ChaseShaco'), ('Dekar173', 'Sanchovies'), ('Dekar173', 'KarasMai'), ('Dekar173', 'Yassuo'), ('Dekar173', 'ForestWithin'), ('Dekar173', 'foggedftw2'), ('Dekar173', 'Swifte'), ('Overpow', 'Kikis1205'), ('Overpow', 'Nervarien'), ('Overpow', 'Kubon_'), ('Overpow', 'Nieuczesana'), ('Overpow', 'RandomBruceTV'), ('Overpow', 'Ortis'), ('Overpow', 'ArQuel'), ('接接', '狂暴小建'), ('接接', 'relaxing234'), ('接接', '咪咪蛋'), ('接接', '超負荷'), ('接接', '逼比'), ('接接', '勝敗難免'), ('接接', '龍爪手'), ('接接', '萌萌小蝶'), ('接接', '獅子丸'), ('接接', '矮子娃娃'), ('Voyboy', 'Aphromoo'), ('Voyboy', 'Scarra'), ('Voyboy', 'C9Sneaky'), ('Voyboy', 'imaqtpie'), ('Voyboy', 'IWillDominate'), ('Voyboy', 'imls'), ('Voyboy', 'Shiphtur'), ('Voyboy', 'Nightblue3'), ('Voyboy', 'Trick2g'), ('Voyboy', 'Dyrus'), ('Voyboy', 'Becca'), ('Voyboy', 'boxbox'), ('Voyboy', 'Rakin'), ('Voyboy', 'loltyler1'), ('Voyboy', 'TFBlade'), ('Voyboy', 'Sanchovies'), ('Voyboy', 'Yassuo'), ('Voyboy', 'ForestWithin'), ('Kikis1205', 'Overpow'), ('Kikis1205', 'Voyboy'), ('Kikis1205', 'Scarra'), ('Kikis1205', 'LVPes'), ('Kikis1205', 'Nervarien'), ('Kikis1205', 'd4mm_'), ('Kikis1205', 'Nzq123'), ('Kikis1205', 'Kubon_'), ('Kikis1205', 'Dyrus'), ('Kikis1205', 'Wingsofdeath'), ('Kikis1205', 'boxbox'), ('Kikis1205', 'Broeki1'), ('Kikis1205', 'ThePowerOfEvil'), ('Kikis1205', 'ElmiilloR'), ('Kikis1205', 'Tabasko'), ('Kikis1205', 'SaltyTeemo'), ('Kikis1205', 'loltyler1'), ('Kikis1205', 'Nieuczesana'), ('Kikis1205', 'CoreJJ'), ('Kikis1205', 'RandomBruceTV'), ('Kikis1205', 'lol_nemesis'), ('Kikis1205', 'Remilia'), ('Kikis1205', 'ArQuel'), ('Dhalucard', 'SummonersInnLive'), ('Dhalucard', 'kev1nTV'), ('Dhalucard', 'Sissorstream'), ('Dhalucard', 'DoktorFroid'), ('Dhalucard', 'NoWay4u_Sir'), ('Locodoco', 'Voyboy'), ('Locodoco', 'Aphromoo'), ('Locodoco', 'Scarra'), ('Locodoco', 'travisgafford'), ('Locodoco', 'Pobelter'), ('Locodoco', 'IWillDominate'), ('Locodoco', 'imls'), ('Locodoco', 'Lourlo'), ('Locodoco', 'Trick2g'), ('Locodoco', 'Dyrus'), ('Locodoco', 'saintvicious'), ('Locodoco', 'stunt'), ('Locodoco', 'Froggen'), ('Locodoco', 'wickd'), ('Locodoco', 'boxbox'), ('Locodoco', 'NickiTaylor'), ('Locodoco', 'Akaadian'), ('Locodoco', 'Moonstreuxx'), ('Locodoco', 'Kandyland'), ('Locodoco', 'luxxbunny'), ('Locodoco', 'YourPrincess'), ('Locodoco', '404BrokenBlade'), ('Locodoco', 'yougelly'), ('Locodoco', 'Bustin'), ('Locodoco', 'keanelol'), ('Locodoco', 'DisguisedToast'), ('Locodoco', 'Metaphor'), ('Locodoco', 'STPeach'), ('Locodoco', 'cxlibri'), ('Locodoco', 'Yassuo'), ('Locodoco', 'Yamikazexz'), ('Locodoco', 'Swifte'), ('Locodoco', 'bang'), ('Locodoco', '매드라이프_'), ('Locodoco', '앰비션_'), ('Locodoco', 'QuarterJade'), ('Aphromoo', 'Voyboy'), ('Aphromoo', 'Locodoco'), ('Aphromoo', 'Scarra'), ('Aphromoo', 'C9Sneaky'), ('Aphromoo', 'imaqtpie'), ('Aphromoo', 'Pobelter'), ('Aphromoo', 'IWillDominate'), ('Aphromoo', 'Trick2g'), ('Aphromoo', 'Darshan'), ('Aphromoo', 'Wingsofdeath'), ('Aphromoo', 'stunt'), ('Aphromoo', 'TheOddOrange'), ('Aphromoo', '마타타마'), ('Aphromoo', 'Natsumiii'), ('Aphromoo', 'yvonnie'), ('Aphromoo', 'Moonstreuxx'), ('Aphromoo', 'loltyler1'), ('Aphromoo', 'luxxbunny'), ('Aph ...
# 5380

# %%
v = [(x,y) for x,y in dict_lol if x =='Voyboy' and y == 'loltyler1']
print(v)
# Out:
# [('Voyboy', 'loltyler1')]

# %%
g = fm.Graph(nx.DiGraph())

g.add_edges_from([("b", "a")])
g.label_nodes()
g.move('kamada_kawai')
g.draw()
# Out:
# <div>
#
#
#             <div id="ab73ff92-3e97-4fdc-9424-0c4a77a995e8" class="plotly-graph-div" style="height:450px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ab73ff92-3e97-4fdc-9424-0c4a77a995e8")) {
#                     Plotly.newPlot(
#                         'ab73ff92-3e97-4fdc-9424-0c4a77a995e8',
#                         [{"hoverinfo": "none", "line": {"color": "rgb(0, 0, 0)", "width": 1}, "mode": "lines", "type": "scatter", "x": [1.0, 0.0, null, 0.012603047500509671, 0.02668201680125305, null, 0.012603047500509671, 0.022604380502606596, null], "y": [1.0, 0.0, null, 0.012603047500509671, 0.017839469464182696, null, 0.012603047500509671, 0.031446927839676946, null]}, {"hoverinfo": "none", "marker": {"color": "rgb(255, 255, 255)", "line": {"color": "rgb(0, 0, 0)", "width": 1}, "size": 20}, "mode": "markers+text", "text": ["b", "a"], "textfont": {"color": "rgb(0, 0, 0)"}, "textposition": "middle center", "type": "scatter", "x": [1.0, 0.0], "y": [1.0, 0.0]}, {"hoverinfo": "none", "mode": "text", "text": [null], "textfont": {"color": "rgb(0, 0, 0)"}, "textposition": "middle center", "type": "scatter", "x": [0.5072440361387628], "y": [0.47582596558169954]}, {"hoverinfo": "none", "marker": {"color": "rgba(255, 255, 255, 0.0)", "line": {"color": "rgba(255, 255, 255, 0.0)", "width": 0}, "size": 0}, "mode": "markers", "type": "scatter", "x": [0.5, 0.0, 1.0, 0.5], "y": [0.0, 0.5, 0.5, 1.0]}],
#                         {"height": 450, "margin": {"b": 0, "l": 0, "r": 0, "t": 0}, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterter ...

# %%
def make_time_graph(conn,time_1,time_2,game_id):
    r = get_streams_from_game(conn,time_1,time_2,game_id)
    sizes = {}
    print(len(r))
    #get_streams_from_game(connection,time1,time2,game)
    gt = fm.Graph(nx.DiGraph()) # grafo temporario
    for node in r:
        gt.add_node(node[2])
        sizes[node[2]] = node[6]
    for stream in r:
        # print(stream[1],stream[2]) # _user_id e _user_name
        links = get_links_user(connection, stream[1])
        #print(links)
        if links:
            for link in links:
                name1 = stream[2] #get_username_from_id(connection,link[1])[0]
                name2 = get_username_from_id(connection,link[2])[0]
                #gt.add_edges_from([(name1),(name2)])
                if name2 in gt:
                    gt.add_edges_from([(name1, name2)])
            
    return gt, sizes

def segue(_from,_to,dicti):
    a = print([(x,y) for x,y in dicti if x ==node[0] and y == node2[0]])
    if a != []:
        return True
    return False

def generate_dataframe(Antes,Depois,dicti):
    # Antes eh [0] lista de sizes e [1] eh o total view de todo mundo somado
    # Depois eh [0] lista de sizes e [1] eh o total view de todo mundo somado
    
    df=[]
    gt = fm.Graph(nx.DiGraph()) # Grafo
    leavers=get_leavers(Antes[0],Depois[0]) # Lista de sizes
    for node in Antes[0]:
        print(node[0])
        for node2 in Antes[0]:
            print([(x,y) for x,y in dicti if x ==node[0] and y == node2[0]])
    return
        
    
    if leavers !=[]:
        print('SAIU')
        for i in Depois[0]:
            a=[tup for tup in Antes[0] if tup[0] == i[0]]  # Checa se o cara ta no Depois
            if a!=[]:
                
                #print(leavers)
                #print(a[0])
                data=[]
                #print(a,i)
                data.append(i[0])
                
                # Calcula percentagem delta
                percentAntes= (a[0][1]/Antes[1])*100 # a01 eh view da stream
                #print("Porcentagem antes ",percentAntes)
                percentDepois= (i[1]/Depois[1])*100 # i1 view dps
                #print("Porcentagem depois ",percentDepois)
                dif=(percentDepois-percentAntes)
                data.append(dif)
                
                # Pega os viwers totais
                TotalViewer=get_total_viewer_count(connection,i[0])[0]
                data.append(TotalViewer)
                
                # Checa se os leavers seguiam ele
                count_leaver_that_follow = 0
                for leaver in leavers:
                    #print(leaver[1],a[0][2])
                    links = get_links_from_to(connection, leaver[1], a[0][2]) # Checa se o leaver segue o user
                    if (links):
                        #print("Usuario "+leaver[0]+" saiu. E seguia o "+a[0][0])
                        count_leaver_that_follow+=1
                        
                data.append(count_leaver_that_follow)
                data.append(i[3])
                df.append(data)
            #break
    return df


                
data=generate_dataframe(streams1,streams2,dict_lol)
# Out:
# Faker
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# 한동숙
# [('한동숙', 'Faker')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# 超負荷
# []
# []
# []
# []
# []
# [('超負荷', '接接')]
# []
# []
# []
# []
# []
# []
# [('超負荷', '狂暴小建')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# 괴물쥐123
# []
# [('괴물쥐123', '한동숙')]
# []
# []
# []
# []
# []
# []
# []
# []
# [('괴물쥐123', '과로사1')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# Solary
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [('Solary', 'GoBGG')]
# []
# []
# []
# []
# []
# []
# [('Solary', 'Corobizar')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [('Solary', 'OgamingLoL')]
# []
# []
# []
# []
# []
# []
# 接接
# []
# []
# [('接接', '超負荷')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [('接接', '狂暴小建')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [('接接', '勝敗難免')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# Rakin
# [('Rakin', 'Faker')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [('Rakin', 'Buerinho')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# RATIRL
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# NoWay4u_Sir
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [('NoWay4u_Sir', 'Broeki1')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [('NoWay4u_Sir', 'EisohneWaffel')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# 테디이
# [('테디이', 'Faker')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [('테디이', 'lol_Khan')]
# []
# []
# []
# []
# []
# []
# [('테디이', 'clid')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# 과로사1
# [('과로사1', 'Faker')]
# []
# []
# [('과로사1', '괴물쥐123')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# スタンミ
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [('スタンミ', 'しゃるる')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [('スタンミ', 'たぬき忍者')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# 狂暴小建
# [('狂暴小建', 'Faker')]
# []
# [('狂暴小建', '超負荷')]
# []
# []
# [('狂暴小建', '接接')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [('狂暴小建', '丁特')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# GoBGG
# []
# []
# []
# []
# [('GoBGG', 'Solary')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [('GoBGG', 'Corobizar')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [('GoBGG', 'OgamingLoL')]
# []
# []
# [('GoBGG', 'armatvhs')]
# []
# []
# []
# SoloRenektonOnly
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [('SoloRenektonOnly', 'SirhcEz')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [('SoloRenektonOnly', 'wickd')]
# []
# lol_Khan
# [('lol_Khan', 'Faker')]
# []
# []
# []
# []
# []
# []
# []
# []
# [('lol_Khan', '테디이')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [('lol_Khan', 'clid')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# しゃるる
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [('しゃるる', 'スタンミ')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [('しゃるる', 'たぬき忍者')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# xxBloodyNyuuxx
# []
# []
# []
# []
# []
# []
# []
# []
# [('xxBloodyNyuuxx', 'NoWay4u_Sir')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [('xxBloodyNyuuxx', 'Broeki1')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [('xxBloodyNyuuxx', 'EisohneWaffel')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# Overpow
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [('Overpow', 'Kubon_')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# SirhcEz
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# Corobizar
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [('Corobizar', 'OgamingLoL')]
# []
# []
# []
# []
# []
# []
# 루시아
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# clid
# [('clid', 'Faker')]
# []
# []
# []
# []
# []
# []
# []
# []
# [('clid', '테디이')]
# []
# []
# []
# []
# []
# [('clid', 'lol_Khan')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# 丁特
# [('丁特', 'Faker')]
# []
# []
# []
# []
# [('丁特', '接接')]
# []
# []
# []
# []
# []
# []
# [('丁特', '狂暴小建')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [('丁特', '勝敗難免')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# CarritosKami
# []
# []
# []
# []
# []
# []
# []
# []
# [('CarritosKami', 'NoWay4u_Sir')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [('CarritosKami', 'Overpow')]
# []
# []
# []
# []
# []
# []
# []
# [('CarritosKami', 'Werlyb')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# 짬타수아
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# Werlyb
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [('Werlyb', 'CarritosKami')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# 실프_
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# Dhalucard
# []
# []
# []
# []
# []
# []
# []
# []
# [('Dhalucard', 'NoWay4u_Sir')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# Broeki1
# []
# []
# []
# []
# []
# []
# []
# []
# [('Broeki1', 'NoWay4u_Sir')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [('Broeki1', 'wickd')]
# []
# Kubon_
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [('Kubon_', 'Overpow')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# 인간젤리
# []
# [('인간젤리', '한동숙')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# 勝敗難免
# [('勝敗難免', 'Faker')]
# []
# []
# []
# []
# [('勝敗難免', '接接')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [('勝敗難免', '丁特')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# DuendePablo
# [('DuendePablo', 'Faker')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# Buerinho
# [('Buerinho', 'Faker')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [('Buerinho', 'jean_mago')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# loltiesel
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# jean_mago
# [('jean_mago', 'Faker')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [('jean_mago', 'Buerinho')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ragner7
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# たぬき忍者
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [('たぬき忍者', 'スタンミ')]
# []
# []
# []
# []
# [('たぬき忍者', 'しゃるる')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# fragolaqt
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# EisohneWaffel
# [('EisohneWaffel', 'Faker')]
# []
# []
# []
# []
# []
# []
# []
# [('EisohneWaffel', 'NoWay4u_Sir')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [('EisohneWaffel', 'Broeki1')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# flor3nce
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# Pierce
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# OgamingLoL
# []
# []
# []
# []
# [('OgamingLoL', 'Solary')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# Bizzleberry
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [('Bizzleberry', 'SirhcEz')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# MiyuGODVelk
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# armatvhs
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# GeneraL_HS_
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# wickd
# []
# []
# []
# []
# []
# []
# []
# [('wickd', 'RATIRL')]
# [('wickd', 'NoWay4u_Sir')]
# []
# []
# []
# []
# []
# [('wickd', 'SoloRenektonOnly')]
# []
# []
# []
# []
# [('wickd', 'SirhcEz')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [('wickd', 'Broeki1')]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# 피아노캣
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []

# %%
df = pd.DataFrame(data, columns = ['UserName', 'DeltaPercentage',"TotalViewerCount","LeaversFollowers","RequestTime"]) 
df
# Out:
#             UserName  DeltaPercentage  TotalViewerCount  LeaversFollowers  \
# 0                한동숙         8.920359          50998396                 1
# 1                超負荷         1.926891          10773880                 0
# 2                 接接         2.840147         103055955                 0
# 3        NoWay4u_Sir         3.008032          38866827                 0
# 4             Solary         1.087689          87110241                 0
# 5              Rakin         1.865333          44907439                 0
# 6   SoloRenektonOnly         1.348641          11653376                 0
# 7               スタンミ         1.126979           5913220                 0
# 8               과로사1         0.917687           1894834                 1
# 9               狂暴小建         0.758456          47640237                 0
# 10             GoBGG         0.672012          17648632                 0
# 11           Overpow         0.810869          31270352                 0
# 12           SirhcEz         0.738243          61284566                 0
# 13              しゃるる         0.498723           3956895                 0
# 14                丁特         0.659392          31232435                 0
# 15            Werlyb         0.831847           1975195                 0
# 16         Corobizar         0.568221           7754001                 0
# 17               루시아         0.353702           5064775                 0
# 18              짬타수아         0.474665          11964711                 0
# 19      CarritosKami         0.290677           8061674                 0
# 20               실프_         0.393196          13482867                 0
# 21         Dhalucard         0.348339           6366882                 0
# 22              인간젤리         0.489166           8507920                 0
# 23            Kubon_         0.423458          29265742                 0
# 24           Broeki1         0.224810          15688869                 0
# 25       DuendePablo         0.316273          15186251                 0
# 26          Buerinho         0.269278           2318280                 0
# 27    xxBloodyNyuuxx        -0.589386           2909931                 0
# 28           ragner7         0.224398            523316                 0
# 29         loltiesel         0.184635            740915                 0
# 30          flor3nce         0.215580           1845474                 0
# 31       MiyuGODVelk         0.243844           1262391                 0
# 32             たぬき忍者         0.124409           4806993                 0
# 33             wickd         0.252389          25622606                 0
694, datetime.datetime(2019, 11, 13, 13, 30, 7)), ('flor3nce', 529, 41316309, datetime.datetime(2019, 11, 13, 13, 30, 7)), ('PinkWardlol', 508, 72700357, datetime.datetime(2019, 11, 13, 13, 30, 7)), ('하루123', 507, 147519858, datetime.datetime(2019, 11, 13, 13, 30, 7)), ('MiyuGODVelk', 499, 103588982, datetime.datetime(2019, 11, 13, 13, 30, 7)), ('たぬき忍者', 496, 143662611, datetime.datetime(2019, 11, 13, 13, 30, 7)), ('Terenas', 490, 30264374, datetime.datetime(2019, 11, 13, 13, 30, 7)), ('wickd', 484, 38865245, datetime.datetime(2019, 11, 13, 13, 30, 7)), ('西門夜說', 476, 27862224, datetime.datetime(2019, 11, 13, 13, 30, 8)), ('OgamingLoL', 460, 71852533, datetime.datetime(2019, 11, 13, 13, 30, 8)), ('EisohneWaffel', 448, 76588774, datetime.datetime(2019, 11, 13, 13, 30, 8)), ('Bizzleberry', 440, 42745283, datetime.datetime(2019, 11, 13, 13, 30, 8)), ('루밍쨩', 421, 145143869, datetime.datetime(2019, 11, 13, 13, 30, 8)), ('jean_mago', 403, 245829588, datetime.datetime(2019, 11, 13, 13, 30, 8)), ('Pierce', 403, 27885601, datetime.datetime(2019, 11, 13, 13, 30, 8)), ('fragolaqt', 372, 139695853, datetime.datetime(2019, 11, 13, 13, 30, 8)), ('PanunuLoL', 366, 44206377, datetime.datetime(2019, 11, 13, 13, 30, 9)), ('MedicCasts', 337, 86266216, datetime.datetime(2019, 11, 13, 13, 30, 9)), ('夏如芝', 337, 448625063, datetime.datetime(2019, 11, 13, 13, 30, 9))], 93504)

# %%
time1 = datetime(2019, 11, 15, 17, 0) # 2019-11-11 17:00:02
time2 = datetime(2019, 11, 15, 18,0) # 2019-11-16 04:45:07

def get_progression(start_date,end_date):
    DBase=[]
    data = start_date
    safedata=start_date+timedelta(minutes=10)
    while(data < end_date):
        stream1=list_streamer_time(data,safedata,game)
        streams2=list_streamer_time(data+timedelta(minutes=30),safedata+timedelta(minutes=30),game)
        DBase+=generate_dataframe(streams1,streams2)
        data += timedelta(minutes=30)
        safedata+=timedelta(minutes=30)
    df = pd.DataFrame(DBase, columns = ['UserName', 'DeltaPercentage',"TotalViewerCount","LeaversFollowers","RequestTime"])
    print("Acaaabou!")
    return df

multipla = get_progression(time1,time2)
# Out:
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# SAIU
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pymysql/connections.py in _read_bytes(self, num_bytes)
#     690             try:
# --> 691                 data = self._rfile.read(num_bytes)
#     692                 break
#
# /usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/socket.py in readinto(self, b)
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#
# ConnectionResetError: [Errno 54] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-9-a117bb7858eb> in <module>
#      17     return df
#      18
# ---> 19 multipla = get_progression(time1,time2)
#
# <ipython-input-9-a117bb7858eb> in get_progression(start_date, end_date)
#      10         stream1=list_streamer_time(data,safedata,game)
#      11         streams2=list_streamer_time(data+timedelta(minutes=30),safedata+timedelta(minutes=30),game)
# ---> 12         DBase+=generate_dataframe(streams1,streams2)
#      13         data += timedelta(minutes=30)
#      14         safedata+=timedelta(minutes=30)
#
# <ipython-input-6-c6e3f0461483> in generate_dataframe(Antes, Depois)
#      33                 for leaver in leavers:
#      34                     #print(leaver[1],a[0][2])
# ---> 35                     links = get_links_from_to(connection, leaver[1], a[0][2]) # Checa se o leaver segue o user
#      36                     if (links):
#      37                         #print("Usuario "+leaver[0]+" saiu. E seguia o "+a[0][0])
#
# <ipython-input-5-9ca363530666> in get_links_from_to(conn, from_id, to_id)
#       7     with conn.cursor() as cursor:
#       8         cursor.execute(
# ----> 9             'SELECT * FROM links WHERE from_id = %s AND to_id = %s',(from_id, to_id))
#      10         res = cursor.fetchall()
#      11         if res:
#
# /usr/local/lib/python3.7/site-packages/pymysql/cursors.py in execute(self, query, args)
#     168         query = self.mogrify(query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#     172         return result
#
# /usr/local/lib/python3.7/site-packages/pymysql/cursors.py in _query(self, q)
#     326         self._last_executed = q
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#     330         return self.rowcount
#
# /usr/local/lib/python3.7/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     515                 sql = sql.encode(self.encoding, 'surrogateescape')
#     516         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 517         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     518         return self._affected_rows
#     519
#
# /usr/local/lib/python3.7/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#     730         else:
#     731             result = MySQLResult(self)
# --> 732             result.read()
#     733         self._result = result
#     734         if result.server_status is not None:
#
# /usr/local/lib/python3.7/site-packages/pymysql/connections.py in read(self)
#    1073     def read(self):
#    1074         try:
# -> 1075             first_packet = self.connection._read_packet()
#    1076
#    1077             if first_packet.is_ok_packet():
#
# /usr/local/lib/python3.7/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     655         buff = b''
#     656         while True:
# --> 657             packet_header = self._read_bytes(4)
#     658             #if DEBUG: dump_packet(packet_header)
#     659
#
# /usr/local/lib/python3.7/site-packages/pymysql/connections.py in _read_bytes(self, num_bytes)
#     697                 raise err.OperationalError(
#     698                     CR.CR_SERVER_LOST,
# --> 699                     "Lost connection to MySQL server during query (%s)" % (e,))
#     700             except BaseException:
#     701                 # Don't convert unknown exception to MySQLError.
#
# OperationalError: (2013, 'Lost connection to MySQL server during query ([Errno 54] Connection reset by peer)')

# %%
print(multipla)
multipla.to_csv("total.csv")

# %%
fm.linregress(multipla, ['TotalViewerCount', 'LeaversFollowers'], 'DeltaPercentage')

# %%
print(coefs)
