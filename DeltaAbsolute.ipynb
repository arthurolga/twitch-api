# %%
import networkx as nx
import freeman as fm
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
fm.linregress(pd.read_csv('lol.csv'), ['TotalViewerCount','ViewCount','LeaversFollowers','Distance'], 'DeltaAbsolute')
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          DeltaAbsolute   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                  0.021
# Method:                 Least Squares   F-statistic:                     64.61
# Date:                Sat, 14 Dec 2019   Prob (F-statistic):           2.59e-41
# Time:                        15:07:17   Log-Likelihood:                -70174.
# No. Observations:                8715   AIC:                         1.404e+05
# Df Residuals:                    8711   BIC:                         1.404e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
fm.linregress(pd.read_csv('cs.csv'), ['TotalViewerCount','ViewCount','LeaversFollowers','Distance'], 'DeltaAbsolute')
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          DeltaAbsolute   R-squared:                       0.068
# Model:                            OLS   Adj. R-squared:                  0.067
# Method:                 Least Squares   F-statistic:                     170.1
# Date:                Sat, 14 Dec 2019   Prob (F-statistic):          1.82e-106
# Time:                        15:07:17   Log-Likelihood:                -58010.
# No. Observations:                7035   AIC:                         1.160e+05
# Df Residuals:                    7031   BIC:                         1.161e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
fm.linregress(pd.read_csv('jc.csv'), ['TotalViewerCount','ViewCount','LeaversFollowers','Distance'], 'DeltaAbsolute')
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          DeltaAbsolute   R-squared:                       0.066
# Model:                            OLS   Adj. R-squared:                  0.065
# Method:                 Least Squares   F-statistic:                     177.2
# Date:                Sat, 14 Dec 2019   Prob (F-statistic):          4.61e-111
# Time:                        15:07:17   Log-Likelihood:                -59541.
# No. Observations:                7583   AIC:                         1.191e+05
# Df Residuals:                    7579   BIC:                         1.191e+05
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
fm.linregress(pd.read_csv('tt.csv'), ['TotalViewerCount','ViewCount','LeaversFollowers','Distance'], 'DeltaAbsolute')
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          DeltaAbsolute   R-squared:                       0.088
# Model:                            OLS   Adj. R-squared:                  0.088
# Method:                 Least Squares   F-statistic:                     194.4
# Date:                Sat, 14 Dec 2019   Prob (F-statistic):          2.58e-120
# Time:                        15:07:18   Log-Likelihood:                -38452.
# No. Observations:                6024   AIC:                         7.691e+04
# Df Residuals:                    6020   BIC:                         7.694e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...
